# %%
"""
urls = Array.from(document.querySelectorAll('.rg_di .rg_meta')).map(el=>JSON.parse(el.textContent).ou);
window.open('data:text/csv;charset=utf-8,' + escape(urls.join('\n')));
"""

# %%
from fastai.vision import *
download_images('/home/sarzhann/Desktop/CIFAR4/download', '/home/sarzhann/Desktop/CIFAR4/Data/burger')
# Out:
#  Download of https://gastronews.wien/wp-content/uploads/2019/05/iStock-496389174-2.jpg has failed after 5 retries
#  Fix the download manually:
# $ mkdir -p /home/sarzhann/.fastai/data
# $ cd /home/sarzhann/.fastai/data
# $ wget -c https://gastronews.wien/wp-content/uploads/2019/05/iStock-496389174-2.jpg
# $ tar -zxvf iStock-496389174-2.jpg
#
# And re-run your code once the download is successful
#
#
#  Download of http://www.foodtastic.at/content/uploads/2018/11/burger_reschufrisch_foodtastic_mg_0194.jpg has failed after 5 retries
#  Fix the download manually:
# $ mkdir -p /home/sarzhann/.fastai/data
# $ cd /home/sarzhann/.fastai/data
# $ wget -c http://www.foodtastic.at/content/uploads/2018/11/burger_reschufrisch_foodtastic_mg_0194.jpg
# $ tar -zxvf burger_reschufrisch_foodtastic_mg_0194.jpg
#
# And re-run your code once the download is successful
#
#
#  Download of https://www.springlane.de/magazin/wp-content/uploads/2017/05/Sauerkraut-Burger_featured.jpg has failed after 5 retries
#  Fix the download manually:
# $ mkdir -p /home/sarzhann/.fastai/data
# $ cd /home/sarzhann/.fastai/data
# $ wget -c https://www.springlane.de/magazin/wp-content/uploads/2017/05/Sauerkraut-Burger_featured.jpg
# $ tar -zxvf Sauerkraut-Burger_featured.jpg
#
# And re-run your code once the download is successful
#
# Error https://www.harecker.de/blog/wp-content/uploads/2018/04/burger.jpg HTTPSConnectionPool(host='www.harecker.de', port=443): Read timed out. (read timeout=4)
#
#  Download of https://image.brigitte.de/11067512/large1x1-622-622/2369510c7805ce419d585ee9a586bc39/Yl/zucchini-suesskartoffel-burger-mit-chipotle-mayonnaise.jpg has failed after 5 retries
#  Fix the download manually:
# $ mkdir -p /home/sarzhann/.fastai/data
# $ cd /home/sarzhann/.fastai/data
# $ wget -c https://image.brigitte.de/11067512/large1x1-622-622/2369510c7805ce419d585ee9a586bc39/Yl/zucchini-suesskartoffel-burger-mit-chipotle-mayonnaise.jpg
# $ tar -zxvf zucchini-suesskartoffel-burger-mit-chipotle-mayonnaise.jpg
#
# And re-run your code once the download is successful
#
# Error https://i1.wp.com/fullofplants.com/wp-content/uploads/2018/07/high-protein-grillable-vegan-burgers-with-seitan-tvp-thumb-3.jpg?fit=1350%2C1349&ssl=1 HTTPSConnectionPool(host='i1.wp.com', port=443): Read timed out. (read timeout=4)
#
#  Download of https://upload.wikimedia.org/wikipedia/commons/0/0b/RedDot_Burger.jpg has failed after 5 retries
#  Fix the download manually:
# $ mkdir -p /home/sarzhann/.fastai/data
# $ cd /home/sarzhann/.fastai/data
# $ wget -c https://upload.wikimedia.org/wikipedia/commons/0/0b/RedDot_Burger.jpg
# $ tar -zxvf RedDot_Burger.jpg
#
# And re-run your code once the download is successful
#
# Error https://meinheimvorteil.at/wp-content/uploads/2016/04/pulled-pork-burger-lidl-oesterreich.jpg HTTPSConnectionPool(host='meinheimvorteil.at', port=443): Max retries exceeded with url: /wp-content/uploads/2016/04/pulled-pork-burger-lidl-oesterreich.jpg (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7feac076de48>, 'Connection to meinheimvorteil.at timed out. (connect timeout=4)'))
# Error https://recipecontent.fooby.ch/13723_3-2_480-320.jpg HTTPSConnectionPool(host='recipecontent.fooby.ch', port=443): Read timed out. (read timeout=4)
# Error https://az826390.vo.msecnd.net/cdn/media/home/inspiring_recipes/recipes/new_-_b/burger-de-steakhouse-1160x650-bs011131.ashx HTTPSConnectionPool(host='az826390.vo.msecnd.net', port=443): Read timed out. (read timeout=4)
#
#  Download of https://image.brigitte.de/11067578/large1x1-622-622/57d349400058c97d27a9f4b84158917e/Ci/kohle.jpg has failed after 5 retries
#  Fix the download manually:
# $ mkdir -p /home/sarzhann/.fastai/data
# $ cd /home/sarzhann/.fastai/data
# $ wget -c https://image.brigitte.de/11067578/large1x1-622-622/57d349400058c97d27a9f4b84158917e/Ci/kohle.jpg
# $ tar -zxvf kohle.jpg
#
# And re-run your code once the download is successful
#
#
#  Download of https://panmacmillan.azureedge.net/pmk11/panmacmillan/files/media/panmacmillan/blogs-2018/joe-wicks-halloumi-burger-header-min.jpg has failed after 5 retries
#  Fix the download manually:
# $ mkdir -p /home/sarzhann/.fastai/data
# $ cd /home/sarzhann/.fastai/data
# $ wget -c https://panmacmillan.azureedge.net/pmk11/panmacmillan/files/media/panmacmillan/blogs-2018/joe-wicks-halloumi-burger-header-min.jpg
# $ tar -zxvf joe-wicks-halloumi-burger-header-min.jpg
#
# And re-run your code once the download is successful
#
#
#  Download of https://www.mrsflury.com/wp-content/uploads/2017/05/burger-blog1-1024x683.jpg has failed after 5 retries
#  Fix the download manually:
# $ mkdir -p /home/sarzhann/.fastai/data
# $ cd /home/sarzhann/.fastai/data
# $ wget -c https://www.mrsflury.com/wp-content/uploads/2017/05/burger-blog1-1024x683.jpg
# $ tar -zxvf burger-blog1-1024x683.jpg
#
# And re-run your code once the download is successful
#
#
#  Download of http://www.wienerwald.at/wp-content/uploads/2015/12/burger.jpg has failed after 5 retries
#  Fix the download manually:
# $ mkdir -p /home/sarzhann/.fastai/data
# $ cd /home/sarzhann/.fastai/data
# $ wget -c http://www.wienerwald.at/wp-content/uploads/2015/12/burger.jpg
# $ tar -zxvf burger.jpg
#
# And re-run your code once the download is successful
#
# Error https://www.landolakes.com/RecipeManagementSystem/media/Recipe-Media-Files/Recipes/Retail/x17/16961-bbq-pulled-pork-burger-600x600.jpg?ext=.jpg HTTPSConnectionPool(host='www.landolakes.com', port=443): Read timed out. (read timeout=4)
# Error https://cdn.hofst%C3%A4dter.at/app/uploads/2019/04/shutterstock_1006601395_web.jpg HTTPSConnectionPool(host='cdn.hofst%c3%a4dter.at', port=443): Max retries exceeded with url: /app/uploads/2019/04/shutterstock_1006601395_web.jpg (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7feac076dda0>: Failed to establish a new connection: [Errno -2] Name or service not known'))
# Error https://d3hvwccx09j84u.cloudfront.net/0,0/image/5b69822c30006c6978402b34-7ad364d7.jpg HTTPSConnectionPool(host='d3hvwccx09j84u.cloudfront.net', port=443): Read timed out. (read timeout=4)
#
#  Download of http://coastlineseattle.com/wp-content/uploads/2019/02/bcm2450.jpg has failed after 5 retries
#  Fix the download manually:
# $ mkdir -p /home/sarzhann/.fastai/data
# $ cd /home/sarzhann/.fastai/data
# $ wget -c http://coastlineseattle.com/wp-content/uploads/2019/02/bcm2450.jpg
# $ tar -zxvf bcm2450.jpg
#
# And re-run your code once the download is successful
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
